# %%
# !python train_vae_cifar10.py --data_root ./data --out_dir ./runs/cifar10_vae
# Out:
# python3: can't open file '/content/train_vae_cifar10.py': [Errno 2] No such file or directory

# %%
# !pwd
# Out:
# /content
